# %%
import pandas as pd
import requests
import getpass 
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## challenge 01

# %%
url = "https://api.github.com/repos/ironhack-datalabs/data-ber-08-20/forks"

# %%
headers = {"Accept": "application/vnd.github.v3+json",
          "Authorization": f"token {getpass.getpass()}"}

response = requests.get( base + url,
            headers=headers)
# Out:
# ········

# %%
j_resp = response.json()

# %%
j_resp
# Out:
# {'message': 'Bad credentials',
#  'documentation_url': 'https://docs.github.com/rest'}

# %%
list_forks = pd.json_normalize(j_resp)

# %%
list_forks
# Out:
#            id                           node_id                   name  \
# 0   286948340  MDEwOlJlcG9zaXRvcnkyODY5NDgzNDA=         data-ber-08-20
# 1   286493475  MDEwOlJlcG9zaXRvcnkyODY0OTM0NzU=      my-data-ber-08-20
# 2   286486094  MDEwOlJlcG9zaXRvcnkyODY0ODYwOTQ=      my-data-ber-08-20
# 3   286483749  MDEwOlJlcG9zaXRvcnkyODY0ODM3NDk=         data-ber-08-20
# 4   286483201  MDEwOlJlcG9zaXRvcnkyODY0ODMyMDE=         data-ber-08-20
# 5   286481176  MDEwOlJlcG9zaXRvcnkyODY0ODExNzY=         data-ber-08-20
# 6   286480595  MDEwOlJlcG9zaXRvcnkyODY0ODA1OTU=         data-ber-08-20
# 7   286480540  MDEwOlJlcG9zaXRvcnkyODY0ODA1NDA=         data-ber-08-20
# 8   286480500  MDEwOlJlcG9zaXRvcnkyODY0ODA1MDA=         data-ber-08-20
# 9   286480449  MDEwOlJlcG9zaXRvcnkyODY0ODA0NDk=         data-ber-08-20
# 10  286480452  MDEwOlJlcG9zaXRvcnkyODY0ODA0NTI=         data-ber-08-20
# 11  286480439  MDEwOlJlcG9zaXRvcnkyODY0ODA0Mzk=      my-data-ber-08-20
# ...

# %%
list_forks['language']
# Out:
# 0     TSQL
# 1     TSQL
# 2     TSQL
# 3     TSQL
# 4     TSQL
# 5     TSQL
# 6     TSQL
# 7     TSQL
# 8     TSQL
# 9     TSQL
# 10    TSQL
# 11    TSQL
# 12    TSQL
# 13    TSQL
# 14    TSQL
# 15    TSQL
# 16    TSQL
# 17    TSQL
# Name: language, dtype: object

# %%
languages = []
for language in list_forks['language']:
    if language not in languages:
        languages.append (language)

# %%
languages
# Out:
# ['TSQL']

# %% [markdown]
# ## challenge 2

# %%
url2 = "https://api.github.com/repos/ironhack-datalabs/data-ber-08-20/commits"

headers = {"Accept": "application/vnd.github.v3+json",
          "Authorization": f"token {getpass.getpass()}"}

response = requests.get( url = url2, headers=headers)
# Out:
# ········

# %%
j2_resp = response.json()

list_commits = pd.json_normalize(j2_resp)

list_commits['commit.author.date']
# Out:
# 0     2020-08-25T15:57:47Z
# 1     2020-08-25T15:57:35Z
# 2     2020-08-25T13:31:22Z
# 3     2020-08-25T09:22:10Z
# 4     2020-08-24T18:46:18Z
# 5     2020-08-24T18:46:08Z
# 6     2020-08-24T09:23:56Z
# 7     2020-08-21T10:21:30Z
# 8     2020-08-21T07:48:14Z
# 9     2020-08-20T15:44:18Z
# 10    2020-08-20T15:42:41Z
# 11    2020-08-20T13:04:10Z
# 12    2020-08-20T10:33:55Z
# 13    2020-08-20T10:31:09Z
# 14    2020-08-20T08:12:43Z
# 15    2020-08-19T16:02:17Z
# 16    2020-08-19T16:02:06Z
# 17    2020-08-19T14:01:28Z
# 18    2020-08-19T09:47:43Z
# 19    2020-08-19T07:05:50Z
# 20    2020-08-19T07:05:40Z
# 21    2020-08-18T14:18:28Z
# 22    2020-08-18T08:59:43Z
# 23    2020-08-17T16:49:39Z
# 24    2020-08-17T16:02:36Z
# 25    2020-08-17T16:02:29Z
# 26    2020-08-17T09:46:09Z
# 27    2020-08-13T19:21:07Z
# 28    2020-08-13T16:13:23Z
# 29    2020-08-13T16:13:20Z
# Name: commit.author.date, dtype: object

# %%
len(list_commits)
# Out:
# 30

# %% [markdown]
# ## challenge 3
